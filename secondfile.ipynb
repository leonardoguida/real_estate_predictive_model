# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/dataset.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55033 entries, 0 to 55032
# Data columns (total 93 columns):
#  #   Column                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                          --------------  -----
#  0   id_istat                                                                                                        55033 non-null  int64
#  1   id_comune                                                                                                       55032 non-null  object
#  2   cap                                                                                                             55033 non-null  int64
#  3   Provincia                                                                                                       55033 non-null  object
# ...

# %% [markdown]
# # Calcoliamo la media costo alla vendita

# %%
# inserisci all'interno della colonna Media Costo alla Vendita la media delle colonne Costo Minimo alla Vendita e Costo Massimo alla Vendita
df["Media Costo alla Vendita"] = (df["Costo Minimo alla Vendita"] + df["Costo Massimo alla Vendita"]) / 2

# %%
df[df["Tipo di località"].isnull()]
# Out:
#        id_istat           id_comune    cap              Provincia    Regione  \
# 93         1049  Campiglione Fenile  10060                 Torino   Piemonte
# 167        1086               Ciriè  10073                 Torino   Piemonte
# 168        1086               Ciriè  10073                 Torino   Piemonte
# 169        1086               Ciriè  10073                 Torino   Piemonte
# 170        1086               Ciriè  10073                 Torino   Piemonte
# ...         ...                 ...    ...                    ...        ...
# 54580    108034              Muggiò  20835  Monza e della Brianza  Lombardia
# 54581    108034              Muggiò  20835  Monza e della Brianza  Lombardia
# 54582    108034              Muggiò  20835  Monza e della Brianza  Lombardia
# 54976    111064   San Nicolò Gerrei   9040           Sud Sardegna   Sardegna
# 54992    111075             Senorbì   9040           Sud Sardegna   Sardegna
#
# ...

# %%
df.columns
# Out:
# Index(['id_istat', 'id_comune', 'cap', 'Provincia', 'Regione',
#        'Ripartizione Geografica', 'id_catastale', 'Latitudine', 'Longitudine',
#        'Superficie in km2', 'Indice di spopolamento', 'Codice regione',
#        'Capoluogo_enc', 'Reddito Pro-Capite per l'anno di riferimento',
#        'Codice comuni', 'Esercizi a 5 stelle', 'Letti', 'Camere', 'Bagni',
#        'Esercizi a 4 stelle', 'Letti.1', 'Camere.1', 'Bagni.1',
#        'Esercizi a 3 stelle', 'Letti.2', 'Camere.2', 'Bagni.2',
#        'Esercizi a 2 stelle', 'Letti.3', 'Camere.3', 'Bagni.3',
#        'Esercizi a 1 stella', 'Letti.4', 'Camere.4', 'Bagni.4',
#        'Esercizi turistico-alberghiere', 'Letti.5', 'Camere.5', 'Bagni.5',
#        'Esercizi alberghieri', 'Letti.6', 'Camere.6', 'Bagni.6',
#        'Numero campeggi e villaggi turistici', 'Letti.7',
#        'Numero di alloggi in affitto gestiti in forma imprenditoriale',
#        'Letti.8', 'Numero di agriturismi', 'Letti.9',
# ...

# %%
df[df["Tipo di località"].isnull()]["Provincia"].value_counts()
# Out:
# Provincia
# Trento       228
# Vicenza       42
# Como          30
# Belluno       29
# Torino        28
#             ...
# Lodi           2
# Pordenone      2
# Rovigo         1
# Trapani        1
# Isernia        1
# Name: count, Length: 74, dtype: int64

# %%
# Mostrare il nome del comune di Isernia con nan in tipo di località
df[df["Provincia"] == "Trento"]["id_comune"][df["Tipo di località"].isnull()]
# Out:
# 15380    Baselga di Pinè
# 15381    Baselga di Pinè
# 15382    Baselga di Pinè
# 15383    Baselga di Pinè
# 15384    Baselga di Pinè
#               ...
# 16362    Ville di Fiemme
# 16363    Ville di Fiemme
# 16364    Ville di Fiemme
# 16365    Ville di Fiemme
# 16366    Ville di Fiemme
# Name: id_comune, Length: 228, dtype: object
